# %% [markdown]
# <a href="https://colab.research.google.com/github/Nursariutami/resto-krabby-patty/blob/master/latihanPSD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np


Fs = 160
f = 10
sample = 16
A = 30
phase = 45
x = np.arange(sample)
y = np.sin(2 * np.pi * f * x / Fs)
plt.plot(x, y)
plt.xlabel('sample(n)')
plt.ylabel('voltage(V)')
plt.show()
